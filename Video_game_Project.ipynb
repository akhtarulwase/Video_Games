# %% [markdown]
# ### Video_Game_Project

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("D:\Video_Games1.csv")

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df['Genre']
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16714          Action
# 16715          Sports
# 16716       Adventure
# 16717        Platform
# 16718      Simulation
# Name: Genre, Length: 16719, dtype: object

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
df.shape
# Out:
# (16719, 16)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
df.tail(10)
# Out:
#                                                    Name Platform  \
# 16709                                           15 Days       PC
# 16710                     Men in Black II: Alien Escape       GC
# 16711                                  Aiyoku no Eustia      PSV
# 16712                Woody Woodpecker in Crazy Castle 5      GBA
# 16713  SCORE International Baja 1000: The Official Game      PS2
# 16714                     Samurai Warriors: Sanada Maru      PS3
# 16715                                  LMA Manager 2007     X360
# 16716                           Haitaka no Psychedelica      PSV
# 16717                                  Spirits & Spells      GBA
# 16718                               Winning Post 8 2016      PSV
#
#        Year_of_Release       Genre          Publisher  NA_Sales  EU_Sales  \
# 16709           2009.0   Adventure  DTP Entertainment      0.00      0.01
# 16710           2003.0     Shooter         Infogrames      0.01      0.00
# ...

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
 # Display all Racing Games which have Critic_score >= 95.

# %%
Racing_Game=df[(df['Genre']== 'Racing') & (df['Critic_Score'] >=95)]

# %%
Racing_Game
# Out:
#                       Name Platform  Year_of_Release   Genre  \
# 28  Gran Turismo 3: A-Spec      PS2           2001.0  Racing
# 52            Gran Turismo       PS           1997.0  Racing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 28  Sony Computer Entertainment      6.85      5.09      1.87         1.16
# 52  Sony Computer Entertainment      4.02      3.87      2.54         0.52
#
#     Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 28         14.98          95.0          54.0        8.4       314.0
# 52         10.95          96.0          16.0        8.7       138.0
#
#             Developer Rating
# 28  Polyphony Digital      E
# 52  Polyphony Digital      E

# %%
# Display video games whos user_score>9

# %%
df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')

# %%
higher_score = df[(df['User_Score'] > 9)]

# %%
higher_score
# Out:
#                                             Name Platform  Year_of_Release  \
# 65                             Final Fantasy VII       PS           1997.0
# 97                          Super Mario Galaxy 2      Wii           2010.0
# 106                                     Tekken 3       PS           1998.0
# 110                                 Mario Kart 8     WiiU           2014.0
# 111                      Super Smash Bros. Melee       GC           2001.0
# ...                                          ...      ...              ...
# 16230                  Monster Rancher Advance 2      GBA           2002.0
# 16355                                    Deus Ex       PC           2000.0
# 16433  Greg Hastings' Tournament Paintball Max'd      PS2           2006.0
# 16550                Wade Hixton's Counter Punch      GBA           2004.0
# 16631                              Karnaaj Rally      GBA           2003.0
#
# ...

# %%
# 9. Display all unique user_scores

# %%
Scores = df['User_Score'].unique()

# %%
Scores
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7])

# %%
# 10. Display all types of Games

# %%
All_games = df['Genre'].unique()

# %%
All_games
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %%
# 11. Access row 15

# %%
Top_15 = df.iloc[15]

# %%
Top_15
# Out:
# Name               Wii Fit Plus
# Platform                    Wii
# Year_of_Release          2009.0
# Genre                    Sports
# Publisher              Nintendo
# NA_Sales                   9.01
# EU_Sales                   8.49
# JP_Sales                   2.53
# Other_Sales                1.77
# Global_Sales              21.79
# Critic_Score               80.0
# Critic_Count               33.0
# User_Score                  7.4
# User_Count                 52.0
# Developer              Nintendo
# Rating                        E
# Name: 15, dtype: object

# %%
# 12. Display EU_Sales,Global_Sales and Critic_Count of all games using iloc

# %%
Eu_Global_sales_Critic_count= df.iloc[:,[6,9,11]]

# %%
Eu_Global_sales_Critic_count
# Out:
#        EU_Sales  Global_Sales  Critic_Count
# 0         28.96         82.53          51.0
# 1          3.58         40.24           NaN
# 2         12.76         35.52          73.0
# 3         10.93         32.77          73.0
# 4          8.89         31.37           NaN
# ...         ...           ...           ...
# 16714      0.00          0.01           NaN
# 16715      0.01          0.01           NaN
# 16716      0.00          0.01           NaN
# 16717      0.00          0.01           NaN
# 16718      0.00          0.01           NaN
#
# [16719 rows x 3 columns]

# %%
# 13. Display the Name, Genre, and Developer of all games using loc

# %%
name_Games_Developer= df.loc[:,['Name','Genre','Developer']]

# %%
name_Games_Developer
# Out:
#                                 Name         Genre Developer
# 0                         Wii Sports        Sports  Nintendo
# 1                  Super Mario Bros.      Platform       NaN
# 2                     Mario Kart Wii        Racing  Nintendo
# 3                  Wii Sports Resort        Sports  Nintendo
# 4           Pokemon Red/Pokemon Blue  Role-Playing       NaN
# ...                              ...           ...       ...
# 16714  Samurai Warriors: Sanada Maru        Action       NaN
# 16715               LMA Manager 2007        Sports       NaN
# 16716        Haitaka no Psychedelica     Adventure       NaN
# 16717               Spirits & Spells      Platform       NaN
# 16718            Winning Post 8 2016    Simulation       NaN
#
# [16719 rows x 3 columns]

# %%
# 14. Change User_Score data type to float and display all columns data types

# %%
df['User_Score']
# Out:
# 0        8.0
# 1        NaN
# 2        8.3
# 3        8.0
# 4        NaN
#         ...
# 16714    NaN
# 16715    NaN
# 16716    NaN
# 16717    NaN
# 16718    NaN
# Name: User_Score, Length: 16719, dtype: float64

# %%
df['User_Score']=df['User_Score'].astype(float)

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
# 15. Which developer has made how much sales in USD gloabally

# %%
df['Developer']
# Out:
# 0        Nintendo
# 1             NaN
# 2        Nintendo
# 3        Nintendo
# 4             NaN
#            ...
# 16714         NaN
# 16715         NaN
# 16716         NaN
# 16717         NaN
# 16718         NaN
# Name: Developer, Length: 16719, dtype: object

# %%
developer_sales = df.groupby('Developer')['Global_Sales'].sum().reset_index()

# %%
developer_sales
# Out:
#                                   Developer  Global_Sales
# 0                           10tacle Studios          0.16
# 1     10tacle Studios, Fusionsphere Systems          0.11
# 2                            1C, 1C Company          0.03
# 3                    1C, Ino-Co, 1C Company          0.05
# 4                   1C, Various, 1C Company          0.01
# ...                                     ...           ...
# 1691                          odenis studio          0.09
# 1692                                  oeFun          0.02
# 1693                              puzzle.tv          0.12
# 1694                             syn Sophia          3.31
# 1695                                 zSlide          0.03
#
# [1696 rows x 2 columns]

# %%
df = df[df['User_Score'].notna()]

# %%
df
# Out:
#                                     Name Platform  Year_of_Release      Genre  \
# 0                             Wii Sports      Wii           2006.0     Sports
# 2                         Mario Kart Wii      Wii           2008.0     Racing
# 3                      Wii Sports Resort      Wii           2009.0     Sports
# 6                  New Super Mario Bros.       DS           2006.0   Platform
# 7                               Wii Play      Wii           2006.0       Misc
# ...                                  ...      ...              ...        ...
# 16685                            Worms 2       PC           1997.0   Strategy
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0     Action
# 16700                             Breach       PC           2011.0    Shooter
# 16706            STORM: Frontline Nation       PC           2011.0   Strategy
# 16709                            15 Days       PC           2009.0  Adventure
#
# ...

# %%
# 17. Plot the histogram chart with x=User_Score and y=Developer

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))

for developer in df['Developer'].unique():
    developer_scores = df[df['Developer'] == developer]['User_Score']
    plt.hist(developer_scores, alpha=0.5, bins=15, label=developer)

plt.xlabel('User Score')
plt.ylabel('Frequency')
plt.title('Distribution of User Scores by Developer')


plt.show()

# %%
# Get the top 5 developers by the number of games developed
top_developers = df['Developer'].value_counts().nlargest(5).index

# Define a color list
colors = ['blue', 'green', 'red', 'purple', 'orange']

# Create subplots for the top 5 developers
fig, axes = plt.subplots(len(top_developers), 1, figsize=(10, 6 * len(top_developers)), sharex=True)

# Plot the histograms
for i, developer in enumerate(top_developers):
    ax = axes[i]
    developer_scores = df[df['Developer'] == developer]['User_Score']
    ax.hist(developer_scores, bins=15, alpha=0.75, label=developer, color=colors[i])
    ax.set_title(f'Distribution of User Scores for {developer}')
    ax.set_ylabel('Frequency')
    ax.set_xlabel('User Score')
    ax.legend(loc='upper right')  # Add legend for each subplot
    ax.grid(True)  # Add grid lines

    # Annotate the highest bar
    max_height = max(developer_scores.value_counts())
    max_bin = developer_scores.value_counts().idxmax()
    ax.annotate(f'Highest: {max_bin}', xy=(max_bin, max_height), xytext=(max_bin, max_height+5),
                arrowprops=dict(facecolor='black', shrink=0.05))

# Adjust layout to ensure titles and labels fit well
plt.tight_layout()
plt.show()

# %%
# 18. Display all video games.

# %%
df['Genre']=='video_game'
# Out:
# 0        False
# 2        False
# 3        False
# 6        False
# 7        False
#          ...
# 16685    False
# 16696    False
# 16700    False
# 16706    False
# 16709    False
# Name: Genre, Length: 7590, dtype: bool

# %%
# 19. Update NA_Sales with + 5:  (map with lambda)

# %%
df['NA_Sales'] = df['NA_Sales'].map(lambda x: x + 5)

print(df[['Name', 'NA_Sales']])
# Out:
#                                     Name  NA_Sales
# 0                             Wii Sports     46.36
# 2                         Mario Kart Wii     20.68
# 3                      Wii Sports Resort     20.61
# 6                  New Super Mario Bros.     16.28
# 7                               Wii Play     18.96
# ...                                  ...       ...
# 16685                            Worms 2      5.00
# 16696  Metal Gear Solid V: Ground Zeroes      5.00
# 16700                             Breach      5.01
# 16706            STORM: Frontline Nation      5.00
# 16709                            15 Days      5.00
#
# [7590 rows x 2 columns]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14548\1867487110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# 20. Display which Genre has how many games : all_games =  video_games.groupby('Genre').Genre.count()

# %%
all_games = df.groupby('Genre').size().reset_index(name='Count')

# %%
all_games
# Out:
#            Genre  Count
# 0         Action   1830
# 1      Adventure    300
# 2       Fighting    399
# 3           Misc    439
# 4       Platform    428
# 5         Puzzle    128
# 6         Racing    641
# 7   Role-Playing    743
# 8        Shooter    924
# 9     Simulation    344
# 10        Sports   1103
# 11      Strategy    311

# %%
# 21. Create a bar chart for all games.

# %%
all_games = df.groupby('Genre').size().reset_index(name='Count')

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(all_games['Genre'], all_games['Count'], color='skyblue')
plt.xlabel('Genre')
plt.ylabel('Number of Games')
plt.title('Number of Games by Genre')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to ensure everything fits without overlap
plt.show()

# %%
colors = plt.cm.tab20(np.linspace(0, 1, len(all_games)))

# Create a bar chart
plt.figure(figsize=(12, 8))
bars = plt.bar(all_games['Genre'], all_games['Count'], color=colors)
plt.xlabel('Genre')
plt.ylabel('Number of Games')
plt.title('Number of Games by Genre')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to ensure everything fits without overlap

# Add legend
plt.legend(bars, all_games['Genre'], title="Genres", bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
# 22. Which developer has most games sold:- top 20 developer.

# %%
# Group by Developer and sum the Global_Sales
developer_sales = df.groupby('Developer')['Global_Sales'].sum().reset_index()

# Sort the developers by their total global sales in descending order and select the top 20
top_20_developers = developer_sales.sort_values(by='Global_Sales', ascending=False).head(20)

# %%
top_20_developers
# Out:
#                     Developer  Global_Sales
# 824                  Nintendo        529.90
# 368                 EA Sports        170.43
# 351                 EA Canada        137.65
# 992            Rockstar North        119.47
# 216                    Capcom        115.29
# 1254                  Ubisoft        112.63
# 1262         Ubisoft Montreal        107.26
# 1238                 Treyarch        103.00
# 372                EA Tiburon         91.30
# 598             Infinity Ward         77.58
# 1235        Traveller's Tales         74.09
# 1308          Visual Concepts         69.72
# 912         Polyphony Digital         65.20
# 665                    Konami         63.87
# 785                     Namco         61.78
# 809   Neversoft Entertainment         61.17
# 391           Electronic Arts         58.23
# 1117               SquareSoft         54.65
# 1296        Vicarious Visions         53.22
# 356                   EA DICE         51.01

# %%
# 23. Plot the bar chart for the above top 20 developers.

# %%
developer_sales = df.groupby('Developer')['Global_Sales'].sum().reset_index()

# Sort the developers by their total global sales in descending order and select the top 20
top_20_developers = developer_sales.sort_values(by='Global_Sales', ascending=False).head(20)

# Create a bar chart
plt.figure(figsize=(12, 8))
plt.bar(top_20_developers['Developer'], top_20_developers['Global_Sales'], color='skyblue')
plt.xlabel('Developer')
plt.ylabel('Total Global Sales (in millions)')
plt.title('Top 20 Developers by Global Sales')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to ensure everything fits without overlap
plt.show()

# %%
developer_sales = df.groupby('Developer')['Global_Sales'].sum().reset_index()

# Sort the developers by their total global sales in descending order and select the top 20
top_20_developers = developer_sales.sort_values(by='Global_Sales', ascending=False).head(20)

# Generate a color map with unique colors for each bar
colors = plt.cm.tab20(np.linspace(0, 1, len(top_20_developers)))

# Create a bar chart
plt.figure(figsize=(12, 8))
bars = plt.bar(top_20_developers['Developer'], top_20_developers['Global_Sales'], color=colors)
plt.xlabel('Developer')
plt.ylabel('Total Global Sales (in millions)')
plt.title('Top 20 Developers by Global Sales')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to ensure everything fits without overlap

plt.show()
